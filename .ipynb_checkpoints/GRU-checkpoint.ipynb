# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
# ======== 1. Đọc và xử lý dữ liệu ========
df = pd.read_csv("Gold_Futures_Cleaned.csv")
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date')

data = df[['Date', 'Price']].copy()

# Chia 80% train, 20% test theo thời gian (lùi 60 bước cho test)
split_index = int(len(data) * 0.8)
train_data = data[:split_index]
test_data = data[split_index - 60:]

# Chuẩn hóa
scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(train_data[['Price']])
scaled_test = scaler.transform(test_data[['Price']])

# Tạo chuỗi thời gian
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 60
X_train, y_train = create_sequences(scaled_train, seq_length)
X_test, y_test = create_sequences(scaled_test, seq_length)

# Ngày tương ứng để vẽ
train_dates = train_data['Date'].iloc[seq_length:].reset_index(drop=True)
test_dates = test_data['Date'].iloc[seq_length:].reset_index(drop=True)

# %%
# ======== 2. Xây dựng mô hình GRU ========
model = Sequential()
model.add(GRU(64, return_sequences=False, input_shape=(seq_length, 1)))
model.add(Dropout(0.2))  # Thêm Dropout để giảm overfit
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# c:\Users\admin\anaconda3\envs\myenv\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# ======== 3. Callbacks để giảm overfit ========
checkpoint = ModelCheckpoint("best_model.h5", monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6, verbose=1)

# %%
# ======== 4. Huấn luyện mô hình ========
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    callbacks=[checkpoint, early_stop, reduce_lr],
    verbose=0
)
# Out:
# Epoch 1: val_loss improved from inf to 0.00099, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2: val_loss improved from 0.00099 to 0.00087, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: val_loss did not improve from 0.00087
#
# Epoch 4: val_loss improved from 0.00087 to 0.00070, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 5: val_loss did not improve from 0.00070
#
# Epoch 6: val_loss improved from 0.00070 to 0.00062, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: val_loss improved from 0.00062 to 0.00061, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 8: val_loss did not improve from 0.00061
#
# Epoch 9: val_loss improved from 0.00061 to 0.00057, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 10: val_loss did not improve from 0.00057
#
# Epoch 11: val_loss did not improve from 0.00057
#
# Epoch 12: val_loss did not improve from 0.00057
#
# Epoch 13: val_loss improved from 0.00057 to 0.00056, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 14: val_loss did not improve from 0.00056
#
# Epoch 15: val_loss did not improve from 0.00056
#
# Epoch 16: val_loss did not improve from 0.00056
#
# Epoch 17: val_loss improved from 0.00056 to 0.00049, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 18: val_loss did not improve from 0.00049
#
# Epoch 19: val_loss did not improve from 0.00049
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 20: val_loss did not improve from 0.00049
#
# Epoch 21: val_loss did not improve from 0.00049
#
# Epoch 22: val_loss improved from 0.00049 to 0.00046, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 23: val_loss did not improve from 0.00046
#
# Epoch 24: val_loss did not improve from 0.00046
#
# Epoch 25: val_loss improved from 0.00046 to 0.00045, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 26: val_loss did not improve from 0.00045
#
# Epoch 27: val_loss did not improve from 0.00045
#
# Epoch 28: val_loss improved from 0.00045 to 0.00045, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 29: val_loss improved from 0.00045 to 0.00044, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 30: val_loss did not improve from 0.00044
#
# Epoch 31: val_loss improved from 0.00044 to 0.00043, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 32: val_loss did not improve from 0.00043
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 33: val_loss improved from 0.00043 to 0.00043, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 34: val_loss did not improve from 0.00043
#
# Epoch 35: val_loss did not improve from 0.00043
#
# Epoch 36: val_loss improved from 0.00043 to 0.00043, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 37: val_loss did not improve from 0.00043
#
# Epoch 38: val_loss did not improve from 0.00043
#
# Epoch 39: val_loss did not improve from 0.00043
#
# Epoch 40: val_loss did not improve from 0.00043
#
# Epoch 41: val_loss did not improve from 0.00043
#
# Epoch 42: val_loss did not improve from 0.00043
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 43: val_loss did not improve from 0.00043
#
# Epoch 44: val_loss did not improve from 0.00043
#
# Epoch 45: val_loss did not improve from 0.00043
#
# Epoch 46: val_loss improved from 0.00043 to 0.00042, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 47: val_loss improved from 0.00042 to 0.00042, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 48: val_loss did not improve from 0.00042
#
# Epoch 49: val_loss did not improve from 0.00042
#
# Epoch 50: val_loss did not improve from 0.00042
#
# Epoch 51: val_loss did not improve from 0.00042
#
# Epoch 52: val_loss did not improve from 0.00042
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 53: val_loss did not improve from 0.00042
#
# Epoch 54: val_loss improved from 0.00042 to 0.00042, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 55: val_loss did not improve from 0.00042
#
# Epoch 56: val_loss did not improve from 0.00042
#
# Epoch 57: val_loss did not improve from 0.00042
#
# Epoch 58: val_loss did not improve from 0.00042
#
# Epoch 59: val_loss did not improve from 0.00042
#
# Epoch 60: val_loss did not improve from 0.00042
#
# Epoch 61: val_loss did not improve from 0.00042
#
# Epoch 62: val_loss did not improve from 0.00042
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 63: val_loss did not improve from 0.00042
#
# Epoch 64: val_loss improved from 0.00042 to 0.00042, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 65: val_loss did not improve from 0.00042
#
# Epoch 66: val_loss did not improve from 0.00042
#
# Epoch 67: val_loss did not improve from 0.00042
#
# Epoch 68: val_loss did not improve from 0.00042
#
# Epoch 69: val_loss did not improve from 0.00042
#
# Epoch 70: val_loss did not improve from 0.00042
#
# Epoch 71: val_loss did not improve from 0.00042
#
# Epoch 72: val_loss improved from 0.00042 to 0.00042, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 73: val_loss did not improve from 0.00042
#
# Epoch 74: val_loss did not improve from 0.00042
#
# Epoch 75: val_loss did not improve from 0.00042
#
# Epoch 76: val_loss did not improve from 0.00042
#
# Epoch 77: val_loss did not improve from 0.00042
#
# Epoch 78: val_loss did not improve from 0.00042
#
# Epoch 79: val_loss did not improve from 0.00042
#
# Epoch 80: val_loss did not improve from 0.00042
#
# Epoch 81: val_loss did not improve from 0.00042
#
# Epoch 82: val_loss did not improve from 0.00042
#
# Epoch 82: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 82: early stopping
# Restoring model weights from the end of the best epoch: 72.

# %%
# ======== 5. Dự đoán ========
y_pred = model.predict(X_test)
y_test_inv = scaler.inverse_transform(y_test)
y_pred_inv = scaler.inverse_transform(y_pred)
train_inv = scaler.inverse_transform(y_train)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
# ======== 6. Đánh giá ========
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = mean_absolute_percentage_error(y_test_inv, y_pred_inv) * 100
rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
r2 = r2_score(y_test_inv, y_pred_inv)

print("MAE:", mae)
print("MAPE:", mape)
print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# MAE: 26.281997294809624
# MAPE: 1.0717287623672676
# RMSE: 41.47110164135902
# R2 Score: 0.990418462187666

# %%
# ======== 7. Vẽ biểu đồ Loss ========
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Biểu đồ Loss trong quá trình huấn luyện')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# ======== 8. Vẽ biểu đồ dự đoán ========
plt.figure(figsize=(14, 6))
plt.plot(train_dates, train_inv, label='Dữ liệu huấn luyện', color='black')
plt.plot(test_dates, y_test_inv, label='Dữ liệu thực tế', color='blue')
plt.plot(test_dates, y_pred_inv, label='Dự đoán', color='red')
plt.title('Hiệu suất mô hình dự đoán giá vàng với GRU')
plt.xlabel('Thời gian')
plt.ylabel('Giá vàng')
plt.legend()
plt.grid()

years = pd.to_datetime([f'{y}-01-01' for y in range(2010, 2026, 2)])
plt.xticks(ticks=years, labels=[str(y.year) for y in years])
plt.show()
